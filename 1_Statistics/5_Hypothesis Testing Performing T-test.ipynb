# %% [markdown]
# ## In this notebook We'll understand t-test

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Single sample t-test workflow for the titanic Age column

# %%
train = pd.read_csv("5_train.csv").drop(columns=["Survived"])
test = pd.read_csv("5_test.csv")

# %%
df = pd.concat([train, test]).sample(1309)
df.head()
# Out:
#      PassengerId  Pclass                                               Name  \
# 644          645       3                             Baclini, Miss. Eugenie
# 519          520       3                                Pavlovic, Mr. Stefo
# 234         1126       1                          Cumings, Mr. John Bradley
# 741          742       1                      Cavendish, Mr. Tyrell William
# 161          162       2  Watt, Mrs. James (Elizabeth "Bessie" Inglis Mi...
#
#         Sex    Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 644  female   0.75      2      1        2666  19.2583   NaN        C
# 519    male  32.00      0      0      349242   7.8958   NaN        S
# 234    male  39.00      1      0    PC 17599  71.2833   C85        C
# 741    male  36.00      1      0       19877  78.8500   C46        S
# 161  female  40.00      0      0  C.A. 33595  15.7500   NaN        S

# %%
pop = df["Age"].dropna()

# %%
sample_size = 25
num_sample = 20

samples = []
for i in range(num_sample):
    sample = pop.sample(n=sample_size, replace=False)  # replace=False Once an observation is selected, it cannot be selected again
    samples.append(sample)

samples = np.array(samples)
samples = samples.ravel()
samples.shape
# Out:
# (500,)

# %%
hypothesized_mean = 30

# %%
import scipy.stats as stats

t_statistic, p_value = stats.ttest_1samp(samples, hypothesized_mean)
print("T-Statistic: ",t_statistic)
print("P-Value: ",p_value)
# Out:
# T-Statistic:  -0.11781180651011493
# P-Value:  0.9062641801724839

# %%
alpha = 0.05

if p_value < alpha:
    print("Reject the null hypothesis.")
else:
    print("Fail to reject the null hypothesis.")
# Out:
# Fail to reject the null hypothesis.
